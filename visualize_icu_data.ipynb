# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from utils.dataloader import DataLoader

# %%
#load data
# "eicu", "hirid", "miiv", or "mimic"
dl_eicu = DataLoader(dataset_name='hirid')

# %%
#display summary
dl_eicu.data
# Out:
#          stay_id            time  alb  alp  alt  ast   be  bicar  bili  \
# 0              1 0 days 00:00:00  NaN  NaN  NaN  NaN -2.9   23.1   NaN
# 1              1 0 days 01:00:00  NaN  NaN  NaN  NaN  NaN    NaN   NaN
# 2              1 0 days 02:00:00  NaN  NaN  NaN  NaN -4.7   19.9   NaN
# 3              1 0 days 03:00:00  NaN  NaN  NaN  NaN  NaN    NaN   NaN
# 4              1 0 days 04:00:00  NaN  NaN  NaN  NaN  NaN    NaN   NaN
# ...          ...             ...  ...  ...  ...  ...  ...    ...   ...
# 1033076    33905 0 days 10:00:00  NaN  NaN  NaN  NaN  NaN    NaN   NaN
# 1033077    33905 0 days 11:00:00  NaN  NaN  NaN  NaN  NaN    NaN   NaN
# 1033078    33905 0 days 12:00:00  NaN  NaN  NaN  NaN  NaN    NaN   NaN
# 1033079    33905 0 days 13:00:00  NaN  NaN  NaN  NaN  NaN    NaN   NaN
# 1033080    33905 0 days 14:00:00  NaN  NaN  NaN  NaN  NaN    NaN   NaN
#
#          bili_dir  ...  phos    plt    po2  ptt   resp    sbp  temp  tnt  \
# ...
