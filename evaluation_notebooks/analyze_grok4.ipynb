# %% [markdown]
# # Grok 4
# ---

# %% [markdown]
# | Parameter         | Value           | Description                                                                                   |
# |-------------------|-----------------|-----------------------------------------------------------------------------------------------|
# | trainer_name      | DummyTrainer    | Name of the trainer                                                                           |
# | mode              | inference       | Mode of operation (inference, training)                                                       |
# | model_id          | grok-4          | Model ID                                      |
# | api_key_name      | XAI_API_KEY     | API key name                                                                                  |
# | type              | LLM             | Type of model (convML for conventional ML, convDL for conventional DL, LLM for language models)|
# | verbose           | 2               | Verbosity level                                                                               |
# | thinking_budget   | 5000            | Number of reasoning tokens to use                                                    |
# | max_new_tokens    | 10000           | Maximum number of new tokens                                                                  |
# | max_length        | 30000           | Maximum length of input sequences                                                             |
# | temperature       | 0.4             | Temperature for sampling (0.0 = greedy sampling)                                              |

# %%
# Imports
import os
import sys
import pandas as pd
import ipywidgets as widgets
from IPython.display import display

sys.path.append(r"C:\Users\janbe\Documents\GitHub Repos\pulse")
from src.eval.llm_analyzer import LLMAnalyzer
from src.eval.pulse_score import PULSEScoreCalculator

# %% [markdown]
# ## Analysis of different prompting approaches
# ---

# %%
model_id = "grok4"

base_output_dir = (
    r"C:\Users\janbe\Documents\GitHub Repos\pulse\output_to_keep\results_benchmark"
)
model_output_dir = os.path.join(base_output_dir, "llms", model_id)
results_output_dir = os.path.join(base_output_dir, r"results_output")
results_output_jsons = os.path.join(results_output_dir, "jsons")
results_json_path = f"{model_id}_results.json"

prompt_approaches = os.listdir(model_output_dir)
for i, approach in enumerate(prompt_approaches, 1):
    print(f"{i}. {approach}")


best_prompt_approach = None
results_dict = {}
mdata_dict = {}
cost_df = pd.DataFrame()

for prompt_approach in prompt_approaches:
    if not os.path.isdir(os.path.join(model_output_dir, prompt_approach)):
        continue

    print("=" * 50)
    print(f"\nPrompting Approach {prompt_approach}\n")

    cat_files = LLMAnalyzer.categorize_files(
        [os.path.join(model_output_dir, prompt_approach)],
        verbose=False,
    )

    df_mdata = LLMAnalyzer.load_metadata(
        cat_files["metadata_files"], verbose=True
    )

    summary = LLMAnalyzer.print_approach_summary(
        df_mdata, input_token_cost=2.5, output_token_cost=10
    )

    # Filter for final prediction step if agent is used
    if "Step Name" in df_mdata.columns:
        df_mdata = df_mdata[df_mdata["Step Name"] == "final_prediction"].reset_index(
            drop=True
        )

    ps = PULSEScoreCalculator()
    pulse_score = ps.calculate_pulse_score_from_raw_data(
        df=df_mdata,
    )
    pulse_score["model_id"] = model_id
    pulse_score["prompting_id"] = prompt_approach
    pulse_score_temp = pulse_score["overall"]["overall_score"]
    results_dict[prompt_approach] = pulse_score
    mdata_dict[prompt_approach] = df_mdata
    cost_df[prompt_approach] = [
        summary["input_cost"].sum(),
        summary["output_cost"].sum(),
        summary["thinking_cost"].sum(),
        summary["total_cost"].sum(),
    ]

    cost_df.index = ["input_cost", "output_cost", "thinking_cost", "total_cost"]
    if best_prompt_approach is None or pulse_score_temp > best_prompt_approach[1]:

        best_prompt_approach = (prompt_approach, pulse_score_temp)

display(cost_df)
print(
    f"\nBest prompt approach: {best_prompt_approach[0]} with PULSE score: {best_prompt_approach[1]}"
)

# Save results as json. Uses pulse-result format
json_output_path = os.path.join(results_output_jsons, f"{model_id}_results.json")
final_json = LLMAnalyzer.save_results_dict_as_json(results_dict, json_output_path)
# Out:
# 1. hybrid_reasoning_agent_preprocessor
# 2. zhu_2024b_zero_shot_preprocessor
# ==================================================
#
# Prompting Approach hybrid_reasoning_agent_preprocessor
#
# Extracting metadata from files:
# Model Name: Grok4, Task: aki, Dataset: eicu, Timestamp: 20250717_164924
# Model Name: Grok4, Task: aki, Dataset: hirid, Timestamp: 20250717_164924
# Model Name: Grok4, Task: aki, Dataset: miiv, Timestamp: 20250717_164924
# Model Name: Grok4, Task: mortality, Dataset: eicu, Timestamp: 20250717_104612
# Model Name: Grok4, Task: mortality, Dataset: hirid, Timestamp: 20250717_104612
# Model Name: Grok4, Task: mortality, Dataset: miiv, Timestamp: 20250717_104612
# Fixed csv file with path C:\Users\janbe\Documents\GitHub Repos\pulse\output_to_keep\results_benchmark\llms\grok4\hybrid_reasoning_agent_preprocessor\Grok4_sepsis_eicu_20250717_164924_metadata.csv and replaced old one.
# Model Name: Grok4, Task: sepsis, Dataset: eicu, Timestamp: 20250717_164924
# Model Name: Grok4, Task: sepsis, Dataset: hirid, Timestamp: 20250723_094246
# Model Name: Grok4, Task: sepsis, Dataset: miiv, Timestamp: 20250723_094246
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 26511
# Total Input Tokens: 15749583
# Total Output Tokens: 3627434
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $75.65
# =================
# Preparing data for Grok4 PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 276.0
#   Probability range: [0.020, 1.000]
#   Probability mean: 0.189
#   Probability std: 0.213
#   Probability median: 0.110
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 20.0
#   Probability range: [0.000, 1.000]
#   Probability mean: 0.126
#   Probability std: 0.208
#   Probability median: 0.050
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 67.0
#   Probability range: [0.020, 0.880]
#   Probability mean: 0.077
#   Probability std: 0.105
#   Probability median: 0.050
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'not-mortality' 'mortality' 'not-sepsis' 'sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Grok4!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  53.628389
# 1        overall_aki  62.462966
# 2       overall_eicu  52.654185
# 3  overall_mortality  54.425089
# 4      overall_hirid  54.894707
# 5     overall_sepsis  43.997113
# 6       overall_miiv  53.336276
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           66.063395  0.569771  0.759637  0.657742  0.997429
# aki_hirid          55.697735  0.352524  0.779469  0.552620  0.992037
# aki_miiv           65.627769  0.542138  0.780589  0.647563  0.999400
# mortality_eicu     52.568925  0.179039  0.811828  0.615975  0.980000
# mortality_hirid    53.161063  0.228721  0.747702  0.639667  0.985000
# mortality_miiv     57.545280  0.357258  0.812500  0.582929  0.985000
# sepsis_eicu        39.330235  0.064241  0.626109  0.487199  0.999592
# sepsis_hirid       55.825324  0.271537  0.827162  0.575538  1.000000
# sepsis_miiv        36.835779  0.029842  0.575813  0.495563  1.000000
# ==================================================
#
# Prompting Approach zhu_2024b_zero_shot_preprocessor
#
# Extracting metadata from files:
# Model Name: Grok4, Task: aki, Dataset: eicu, Timestamp: 20250721_112523
# Model Name: Grok4, Task: aki, Dataset: hirid, Timestamp: 20250721_112523
# Model Name: Grok4, Task: aki, Dataset: miiv, Timestamp: 20250721_112523
# Model Name: Grok4, Task: mortality, Dataset: eicu, Timestamp: 20250721_112523
# Model Name: Grok4, Task: mortality, Dataset: hirid, Timestamp: 20250721_112523
# Model Name: Grok4, Task: mortality, Dataset: miiv, Timestamp: 20250721_112523
# Model Name: Grok4, Task: sepsis, Dataset: eicu, Timestamp: 20250721_112523
# Model Name: Grok4, Task: sepsis, Dataset: hirid, Timestamp: 20250721_112523
# Model Name: Grok4, Task: sepsis, Dataset: miiv, Timestamp: 20250721_112523
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 21223127
# Total Output Tokens: 610222
# Total Thinking Tokens: 11382112.0
# Average Thinking Tokens: 2189.29
# Total Cost (USD): $1083.55
# =================
# Preparing data for Grok4 PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 340.0
#   Probability range: [0.000, 1.000]
#   Probability mean: 0.172
#   Probability std: 0.267
#   Probability median: 0.050
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 143.0
#   Probability range: [0.120, 0.900]
#   Probability mean: 0.503
#   Probability std: 0.292
#   Probability median: 0.325
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2683.0
#   Probability range: [0.120, 0.950]
#   Probability mean: 0.750
#   Probability std: 0.151
#   Probability median: 0.780
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'mortality' 'not-mortality' 'sepsis' 'not-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Grok4!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  48.619000
# 1        overall_aki  54.868221
# 2       overall_eicu  46.777893
# 3  overall_mortality  53.671792
# 4      overall_hirid  45.794051
# 5     overall_sepsis  37.316988
# 6       overall_miiv  53.285057
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           58.043319  0.471881  0.653483  0.616542  0.999035
# aki_hirid          50.609552  0.286759  0.640378  0.588648  1.000000
# aki_miiv           55.951791  0.413449  0.625530  0.637220  1.000000
# mortality_eicu     45.295623  0.098266  0.706605  0.551025  1.000000
# mortality_hirid    47.170931  0.135962  0.697651  0.578286  1.000000
# mortality_miiv     68.548822  0.554127  0.825284  0.677302  1.000000
# sepsis_eicu        36.994737  0.048619  0.548243  0.508773  1.000000
# sepsis_hirid       39.601668  0.122362  0.593360  0.470264  0.999845
# sepsis_miiv        35.354559  0.022910  0.508041  0.524505  1.000000
#                hybrid_reasoning_agent_preprocessor  \
# input_cost                               39.373958
# output_cost                              36.274340
# thinking_cost                             0.000000
# total_cost                               75.648297
#
#                zhu_2024b_zero_shot_preprocessor
# input_cost                            53.057817
# output_cost                            6.102220
# thinking_cost                       1024.390080
# total_cost                          1083.550117
# Best prompt approach: hybrid_reasoning_agent_preprocessor with PULSE score: 53.62838924177906
# Saved 18 result entries to C:\Users\janbe\Documents\GitHub Repos\pulse\output_to_keep\results_benchmark\results_output\jsons\grok4_results.json

# %% [markdown]
# Summary Metrics of all Prompting Appraches

# %%
df_results = LLMAnalyzer.load_metrics_from_prompt_approaches(
    model_output_dir, prompt_approaches
)



LLMAnalyzer.plot_metrics(
    df_results, group=["prompting_id"], title_prefix="Gemini 2.5 Flash - "
)
# Out:
# C:\Users\janbe\Documents\GitHub Repos\pulse\src\eval\llm_analyzer.py:953: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = plot_df.groupby(["Group", "Metric"], as_index=False).agg(

# %% [markdown]
# Metrics per Prompt and Task

# %%
LLMAnalyzer.plot_metrics(
    df_results,
    group=["task_id", "prompting_id"],
    title_prefix="Gemini 2.5 Flash - ",
)
# Out:
# C:\Users\janbe\Documents\GitHub Repos\pulse\src\eval\llm_analyzer.py:953: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = plot_df.groupby(["Group", "Metric"], as_index=False).agg(

# %% [markdown]
# ---
