# %% [markdown]
# # Claude Sonnet 4
# ---

# %% [markdown]
# | Parameter           | Value                      |
# |---------------------|---------------------------|
# | mode                | inference                 |
# | model_id            | claude-sonnet-4-20250514  |
# | api_key_name        | CLAUDE_SONNET_KEY         |
# | type                | LLM                       |
# | thinking_budget     | 5000                      |
# | max_new_tokens      | 10000                     |
# | max_length          | 30000                     |
# | temperature         | 0.4                       |
# | batch_processing    | true                      |

# %%
# Imports
import os
import sys
import pandas as pd
import ipywidgets as widgets
from IPython.display import display

sys.path.append(r"C:\Users\janbe\Documents\GitHub Repos\pulse")
from src.eval.llm_analyzer import LLMAnalyzer
from src.eval.pulse_score import PULSEScoreCalculator

# %% [markdown]
# ## Analysis of different prompting approaches
# ---

# %%
model_id = "claudesonnet4"

# %%
base_output_dir = (
    r"C:\Users\janbe\Documents\GitHub Repos\pulse\output_to_keep\results_benchmark"
)
model_output_dir = os.path.join(base_output_dir, "llms", model_id)
results_output_dir = os.path.join(base_output_dir, r"results_output")
results_output_jsons = os.path.join(results_output_dir, "jsons")
results_json_path = f"{model_id}_results.json"

prompt_approaches = os.listdir(model_output_dir)
for i, approach in enumerate(prompt_approaches, 1):
    print(f"{i}. {approach}")


best_prompt_approach = None
results_dict = {}
mdata_dict = {}
cost_df = pd.DataFrame()

for prompt_approach in prompt_approaches:
    if not os.path.isdir(os.path.join(model_output_dir, prompt_approach)):
        continue

    print("=" * 50)
    print(f"\nPrompting Approach {prompt_approach}\n")

    cat_files = LLMAnalyzer.categorize_files(
        [os.path.join(model_output_dir, prompt_approach)],
        verbose=False,
    )

    df_mdata = LLMAnalyzer.load_metadata(
        cat_files["metadata_files"], verbose=True
    )

    summary = LLMAnalyzer.print_approach_summary(
        df_mdata, input_token_cost=0, output_token_cost=0
    )

    # Filter for final prediction step if agent is used
    if "Step Name" in df_mdata.columns:
        df_mdata = df_mdata[df_mdata["Step Name"] == "final_prediction"].reset_index(
            drop=True
        )

    ps = PULSEScoreCalculator()
    pulse_score = ps.calculate_pulse_score_from_raw_data(
        df=df_mdata,
    )
    pulse_score["model_id"] = model_id
    pulse_score["prompting_id"] = prompt_approach
    pulse_score_temp = pulse_score["overall"]["overall_score"]
    results_dict[prompt_approach] = pulse_score
    mdata_dict[prompt_approach] = df_mdata
    cost_df[prompt_approach] = [
        summary["input_cost"].sum(),
        summary["output_cost"].sum(),
        summary["thinking_cost"].sum(),
        summary["total_cost"].sum(),
    ]

    cost_df.index = ["input_cost", "output_cost", "thinking_cost", "total_cost"]
    if best_prompt_approach is None or pulse_score_temp > best_prompt_approach[1]:

        best_prompt_approach = (prompt_approach, pulse_score_temp)

display(cost_df)
print(
    f"\nBest prompt approach: {best_prompt_approach[0]} with PULSE score: {best_prompt_approach[1]}"
)

# Save results as json. Uses pulse-result format
json_output_path = os.path.join(results_output_jsons, f"{model_id}_results.json")
final_json = LLMAnalyzer.save_results_dict_as_json(results_dict, json_output_path)
# Out:
# 1. hybrid_reasoning_agent_preprocessor
# 2. liu_2023_few_shot_preprocessor
# 3. sarvari_2024_aggregation_preprocessor
# 4. zhu_2024a_cot_preprocessor
# 5. zhu_2024b_one_shot_preprocessor
# 6. zhu_2024b_zero_shot_preprocessor
# ==================================================
#
# Prompting Approach hybrid_reasoning_agent_preprocessor
#
# Extracting metadata from files:
# Model Name: ClaudeSonnet4, Task: aki, Dataset: eicu, Timestamp: 20250711_173050
# Model Name: ClaudeSonnet4, Task: aki, Dataset: hirid, Timestamp: 20250711_173050
# Model Name: ClaudeSonnet4, Task: aki, Dataset: miiv, Timestamp: 20250711_173050
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: eicu, Timestamp: 20250711_173050
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: hirid, Timestamp: 20250711_173050
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: miiv, Timestamp: 20250711_173050
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: eicu, Timestamp: 20250711_173050
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: hirid, Timestamp: 20250711_173050
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: miiv, Timestamp: 20250711_173050
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 26630
# Total Input Tokens: 19492004
# Total Output Tokens: 14545528
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for ClaudeSonnet4 PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 212.0
#   Probability range: [0.020, 1.000]
#   Probability mean: 0.171
#   Probability std: 0.190
#   Probability median: 0.100
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 8.0
#   Probability range: [0.020, 1.000]
#   Probability mean: 0.093
#   Probability std: 0.140
#   Probability median: 0.050
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 17.0
#   Probability range: [0.020, 0.960]
#   Probability mean: 0.069
#   Probability std: 0.065
#   Probability median: 0.060
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'not-mortality' 'mortality' 'not-sepsis' 'sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for ClaudeSonnet4!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  56.864401
# 1        overall_aki  64.333231
# 2       overall_eicu  57.814400
# 3  overall_mortality  63.638688
# 4      overall_hirid  59.315677
# 5     overall_sepsis  42.621284
# 6       overall_miiv  53.463125
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           68.186777  0.601629  0.761455  0.684234  0.999136
# aki_hirid          58.195297  0.406194  0.798578  0.548218  0.996548
# aki_miiv           66.617618  0.573717  0.791142  0.636320  0.999136
# mortality_eicu     66.463247  0.448769  0.781874  0.760354  1.000000
# mortality_hirid    65.853515  0.450918  0.819203  0.708763  0.997600
# mortality_miiv     58.599301  0.448660  0.851799  0.473623  0.992900
# sepsis_eicu        38.793177  0.058223  0.611970  0.491964  0.998714
# sepsis_hirid       53.898219  0.244959  0.799207  0.572408  0.999608
# sepsis_miiv        35.172455  0.028069  0.522611  0.500000  1.000000
# ==================================================
#
# Prompting Approach liu_2023_few_shot_preprocessor
#
# Extracting metadata from files:
# Model Name: ClaudeSonnet4, Task: aki, Dataset: eicu, Timestamp: 20250729_101343
# Model Name: ClaudeSonnet4, Task: aki, Dataset: hirid, Timestamp: 20250728_193144
# Model Name: ClaudeSonnet4, Task: aki, Dataset: miiv, Timestamp: 20250728_193144
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: eicu, Timestamp: 20250728_161357
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: hirid, Timestamp: 20250728_193144
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: miiv, Timestamp: 20250728_193144
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: eicu, Timestamp: 20250729_101343
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: hirid, Timestamp: 20250728_193144
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: miiv, Timestamp: 20250728_193144
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 58778942
# Total Output Tokens: 4785174
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for ClaudeSonnet4 PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 570.0
#   Probability range: [0.020, 0.980]
#   Probability mean: 0.262
#   Probability std: 0.301
#   Probability median: 0.150
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 147.0
#   Probability range: [0.100, 0.920]
#   Probability mean: 0.518
#   Probability std: 0.261
#   Probability median: 0.350
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 1416.0
#   Probability range: [0.150, 0.950]
#   Probability mean: 0.504
#   Probability std: 0.261
#   Probability median: 0.350
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'not-mortality' 'mortality' 'sepsis' 'not-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for ClaudeSonnet4!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  51.529616
# 1        overall_aki  54.167654
# 2       overall_eicu  52.832831
# 3  overall_mortality  59.522084
# 4      overall_hirid  51.477478
# 5     overall_sepsis  40.899109
# 6       overall_miiv  50.278538
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc  ccf
# aki_eicu           57.560362  0.423614  0.668406  0.633050  1.0
# aki_hirid          48.880153  0.273214  0.607984  0.582371  1.0
# aki_miiv           56.062446  0.437574  0.631456  0.611308  1.0
# mortality_eicu     57.825494  0.219926  0.867127  0.645669  1.0
# mortality_hirid    55.276552  0.374728  0.720633  0.562636  1.0
# mortality_miiv     65.464206  0.530840  0.791193  0.642268  1.0
# sepsis_eicu        43.112636  0.064643  0.657203  0.567403  1.0
# sepsis_hirid       50.275729  0.176971  0.732533  0.595944  1.0
# sepsis_miiv        29.308962  0.017827  0.388332  0.467815  1.0
# ==================================================
#
# Prompting Approach sarvari_2024_aggregation_preprocessor
#
# Extracting metadata from files:
# Model Name: ClaudeSonnet4, Task: aki, Dataset: eicu, Timestamp: 20250723_171551
# Model Name: ClaudeSonnet4, Task: aki, Dataset: hirid, Timestamp: 20250723_171551
# Model Name: ClaudeSonnet4, Task: aki, Dataset: miiv, Timestamp: 20250723_171551
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: eicu, Timestamp: 20250722_130446
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: hirid, Timestamp: 20250722_130446
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: miiv, Timestamp: 20250722_130446
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: eicu, Timestamp: 20250725_111145
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: hirid, Timestamp: 20250728_160704
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: miiv, Timestamp: 20250726_113232
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 12388507
# Total Output Tokens: 4883828
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for ClaudeSonnet4 PULSE score calculation...
# Model Type: LLM
#
# ⚠️ Wrongly labled predictions: 7
# Wrongly labeled predictions:
#   - unknown: 7 occurrences
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 673.0
#   Probability range: [0.020, 0.980]
#   Probability mean: 0.281
#   Probability std: 0.317
#   Probability median: 0.150
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 254.0
#   Probability range: [0.250, 0.950]
#   Probability mean: 0.718
#   Probability std: 0.190
#   Probability median: 0.780
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2054.0
#   Probability range: [0.080, 0.950]
#   Probability mean: 0.633
#   Probability std: 0.250
#   Probability median: 0.750
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'unknown' 'mortality' 'not-mortality' 'sepsis'
#  'not-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for ClaudeSonnet4!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  48.481585
# 1        overall_aki  51.967773
# 2       overall_eicu  52.247891
# 3  overall_mortality  54.432908
# 4      overall_hirid  47.410013
# 5     overall_sepsis  39.044074
# 6       overall_miiv  45.786851
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           56.585733  0.465197  0.624433  0.607550  0.999492
# aki_hirid          47.533198  0.242779  0.598772  0.581948  0.999491
# aki_miiv           51.784389  0.387544  0.590639  0.577537  0.997459
# mortality_eicu     59.381142  0.457762  0.758065  0.566437  1.000000
# mortality_hirid    47.439954  0.271933  0.624617  0.525112  1.000000
# mortality_miiv     56.477628  0.363602  0.759470  0.571067  1.000000
# sepsis_eicu        40.776798  0.054496  0.606850  0.557520  0.999918
# sepsis_hirid       47.256888  0.177261  0.697376  0.540995  1.000000
# sepsis_miiv        29.098535  0.018007  0.380642  0.468915  1.000000
# ==================================================
#
# Prompting Approach zhu_2024a_cot_preprocessor
#
# Extracting metadata from files:
# Model Name: ClaudeSonnet4, Task: aki, Dataset: eicu, Timestamp: 20250729_181148
# Model Name: ClaudeSonnet4, Task: aki, Dataset: hirid, Timestamp: 20250729_181148
# Model Name: ClaudeSonnet4, Task: aki, Dataset: miiv, Timestamp: 20250729_181148
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: eicu, Timestamp: 20250729_181148
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: hirid, Timestamp: 20250729_181148
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: miiv, Timestamp: 20250729_181148
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: eicu, Timestamp: 20250729_181148
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: hirid, Timestamp: 20250729_181148
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: miiv, Timestamp: 20250729_181148
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 40073910
# Total Output Tokens: 7969577
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for ClaudeSonnet4 PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 496.0
#   Probability range: [0.050, 0.980]
#   Probability mean: 0.257
#   Probability std: 0.280
#   Probability median: 0.150
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 191.0
#   Probability range: [0.200, 0.950]
#   Probability mean: 0.615
#   Probability std: 0.253
#   Probability median: 0.750
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2033.0
#   Probability range: [0.150, 0.950]
#   Probability mean: 0.651
#   Probability std: 0.260
#   Probability median: 0.780
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'mortality' 'not-mortality' 'sepsis' 'not-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for ClaudeSonnet4!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  50.857742
# 1        overall_aki  53.363618
# 2       overall_eicu  51.764467
# 3  overall_mortality  60.150902
# 4      overall_hirid  48.948932
# 5     overall_sepsis  39.058705
# 6       overall_miiv  51.859827
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           56.130287  0.430344  0.635573  0.617164  0.999492
# aki_hirid          48.992958  0.292533  0.618641  0.556962  0.999745
# aki_miiv           54.967609  0.413347  0.618135  0.616207  0.999593
# mortality_eicu     58.228065  0.333472  0.829493  0.585544  0.999000
# mortality_hirid    51.559741  0.307631  0.679775  0.558098  1.000000
# mortality_miiv     70.664899  0.596657  0.840909  0.685800  0.998700
# sepsis_eicu        40.935049  0.068802  0.608378  0.546955  0.999796
# sepsis_hirid       46.294096  0.206126  0.654798  0.526059  0.999948
# sepsis_miiv        29.946972  0.019389  0.400580  0.473221  0.999949
# ==================================================
#
# Prompting Approach zhu_2024b_one_shot_preprocessor
#
# Extracting metadata from files:
# Model Name: ClaudeSonnet4, Task: aki, Dataset: eicu, Timestamp: 20250729_120135
# Model Name: ClaudeSonnet4, Task: aki, Dataset: hirid, Timestamp: 20250729_120135
# Model Name: ClaudeSonnet4, Task: aki, Dataset: miiv, Timestamp: 20250729_120135
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: eicu, Timestamp: 20250729_120135
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: hirid, Timestamp: 20250729_120135
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: miiv, Timestamp: 20250729_120135
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: eicu, Timestamp: 20250729_120135
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: hirid, Timestamp: 20250729_152856
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: miiv, Timestamp: 20250729_152856
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 38273803
# Total Output Tokens: 4968848
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for ClaudeSonnet4 PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 426.0
#   Probability range: [0.020, 0.980]
#   Probability mean: 0.230
#   Probability std: 0.267
#   Probability median: 0.150
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 218.0
#   Probability range: [0.200, 0.920]
#   Probability mean: 0.634
#   Probability std: 0.214
#   Probability median: 0.720
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 1885.0
#   Probability range: [0.150, 0.950]
#   Probability mean: 0.605
#   Probability std: 0.232
#   Probability median: 0.730
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'mortality' 'not-mortality' 'sepsis' 'not-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for ClaudeSonnet4!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  53.125630
# 1        overall_aki  55.042182
# 2       overall_eicu  55.280212
# 3  overall_mortality  64.077474
# 4      overall_hirid  52.702766
# 5     overall_sepsis  40.257233
# 6       overall_miiv  51.393912
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           59.300771  0.472748  0.660383  0.645401  0.999390
# aki_hirid          49.916530  0.276325  0.647558  0.572201  0.999470
# aki_miiv           55.909245  0.428759  0.626846  0.620250  0.999746
# mortality_eicu     65.843401  0.544136  0.854839  0.585544  0.996500
# mortality_hirid    57.246104  0.436388  0.731869  0.551835  0.998800
# mortality_miiv     69.142918  0.638209  0.830966  0.608669  0.999500
# sepsis_eicu        40.696463  0.065651  0.605186  0.546484  0.999469
# sepsis_hirid       50.945665  0.203317  0.758179  0.567772  0.998277
# sepsis_miiv        29.129572  0.018170  0.380601  0.469857  0.999828
# ==================================================
#
# Prompting Approach zhu_2024b_zero_shot_preprocessor
#
# Extracting metadata from files:
# Model Name: ClaudeSonnet4, Task: aki, Dataset: eicu, Timestamp: 20250709_125732
# Model Name: ClaudeSonnet4, Task: aki, Dataset: hirid, Timestamp: 20250709_125732
# Model Name: ClaudeSonnet4, Task: aki, Dataset: miiv, Timestamp: 20250709_125732
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: eicu, Timestamp: 20250709_125732
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: hirid, Timestamp: 20250709_125732
# Model Name: ClaudeSonnet4, Task: mortality, Dataset: miiv, Timestamp: 20250709_125732
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: eicu, Timestamp: 20250709_125732
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: hirid, Timestamp: 20250709_125732
# Model Name: ClaudeSonnet4, Task: sepsis, Dataset: miiv, Timestamp: 20250709_125732
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 24430757
# Total Output Tokens: 6346975
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $0.00
# =================
# Preparing data for ClaudeSonnet4 PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 404.0
#   Probability range: [0.020, 0.980]
#   Probability mean: 0.229
#   Probability std: 0.268
#   Probability median: 0.150
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 248.0
#   Probability range: [0.250, 0.880]
#   Probability mean: 0.696
#   Probability std: 0.179
#   Probability median: 0.750
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2644.0
#   Probability range: [0.230, 0.950]
#   Probability mean: 0.756
#   Probability std: 0.164
#   Probability median: 0.780
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'mortality' 'not-mortality' 'sepsis' 'not-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for ClaudeSonnet4!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  49.166347
# 1        overall_aki  54.825711
# 2       overall_eicu  47.841237
# 3  overall_mortality  54.177374
# 4      overall_hirid  48.192043
# 5     overall_sepsis  38.495956
# 6       overall_miiv  51.465761
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           59.702244  0.471441  0.663879  0.657149  0.998222
# aki_hirid          48.769313  0.262412  0.618847  0.579373  0.999776
# aki_miiv           56.005575  0.424622  0.615998  0.637594  0.999766
# mortality_eicu     45.218665  0.095806  0.687404  0.572852  0.997700
# mortality_hirid    49.343938  0.335575  0.613892  0.530913  0.999200
# mortality_miiv     67.969519  0.584008  0.848958  0.612290  0.998000
# sepsis_eicu        38.602802  0.061128  0.556213  0.536192  1.000000
# sepsis_hirid       46.462877  0.201828  0.673847  0.516635  1.000000
# sepsis_miiv        30.422189  0.019255  0.388207  0.499292  1.000000
#                hybrid_reasoning_agent_preprocessor  \
# input_cost                                     0.0
# output_cost                                    0.0
# thinking_cost                                  0.0
# total_cost                                     0.0
#
#                liu_2023_few_shot_preprocessor  \
# input_cost                                0.0
# output_cost                               0.0
# thinking_cost                             0.0
# total_cost                                0.0
#
#                sarvari_2024_aggregation_preprocessor  \
# input_cost                                       0.0
# output_cost                                      0.0
# thinking_cost                                    0.0
# total_cost                                       0.0
#
#                zhu_2024a_cot_preprocessor  zhu_2024b_one_shot_preprocessor  \
# input_cost                            0.0                              0.0
# output_cost                           0.0                              0.0
# thinking_cost                         0.0                              0.0
# total_cost                            0.0                              0.0
#
#                zhu_2024b_zero_shot_preprocessor
# input_cost                                  0.0
# output_cost                                 0.0
# thinking_cost                               0.0
# total_cost                                  0.0
# Best prompt approach: hybrid_reasoning_agent_preprocessor with PULSE score: 56.86440066326729
# Saved 54 result entries to C:\Users\janbe\Documents\GitHub Repos\pulse\output_to_keep\results_benchmark\results_output\jsons\claudesonnet4_results.json

# %% [markdown]
# Summary Metrics of all Prompting Appraches

# %%
df_results = LLMAnalyzer.load_metrics_from_prompt_approaches(
    model_output_dir, prompt_approaches
)



LLMAnalyzer.plot_metrics(
    df_results, group=["prompting_id"], title_prefix="Gemini 2.5 Flash - "
)
# Out:
# C:\Users\janbe\Documents\GitHub Repos\pulse\src\eval\llm_analyzer.py:953: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = plot_df.groupby(["Group", "Metric"], as_index=False).agg(

# %% [markdown]
# Metrics per Prompt and Task

# %%
LLMAnalyzer.plot_metrics(
    df_results,
    group=["task_id", "prompting_id"],
    title_prefix="Gemini 2.5 Flash - ",
)
# Out:
# C:\Users\janbe\Documents\GitHub Repos\pulse\src\eval\llm_analyzer.py:953: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = plot_df.groupby(["Group", "Metric"], as_index=False).agg(

# %% [markdown]
# ---
