# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
import json

sys.path.append(r"C:\Users\janbe\Documents\GitHub Repos\pulse")
from src.eval.llm_analyzer import LLMAnalyzer
from src.eval.metrics import calculate_all_metrics

# %%
mdata_path = [
    r"C:\Users\janbe\Documents\GitHub Repos\pulse\output_to_keep\results_benchmark\llms\gemini2p5flash\20250624_101940_gemini2p5flash_zhu_b_zero_shot\Gemini2p5flash_sepsis_miiv_20250624_101940_metadata.csv"
]

output_path = os.path.dirname(mdata_path[0])

df_mdata = LLMAnalyzer.load_metadata(mdata_path)
# Out:
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: miiv, Timestamp: 20250624_101940

# %%
df_mdata
# Out:
#                                           Input Prompt  Target Label  \
# 0    You are an experienced doctor in Intensive Car...             1
# 1    You are an experienced doctor in Intensive Car...             1
# 2    You are an experienced doctor in Intensive Car...             1
# 3    You are an experienced doctor in Intensive Car...             1
# 4    You are an experienced doctor in Intensive Car...             1
# ..                                                 ...           ...
# 985  You are an experienced doctor in Intensive Car...             1
# 986  You are an experienced doctor in Intensive Car...             1
# 987  You are an experienced doctor in Intensive Car...             1
# 988  You are an experienced doctor in Intensive Car...             1
# 989  You are an experienced doctor in Intensive Car...             1
#
#      Predicted Probability Predicted Diagnosis  \
# 0                     0.20       not-diagnosis
# 1                     0.15       not-diagnosis
# 2                     0.15       not-diagnosis
# 3                     0.10       not-diagnosis
# 4                     0.10       not-diagnosis
# ..                     ...                 ...
# 985                   0.20       not-diagnosis
# 986                   0.15       not-diagnosis
# 987                   0.10       not-diagnosis
# 988                   0.20       not-diagnosis
# 989                   0.15       not-diagnosis
#
#                                  Predicted Explanation  Tokenization Time  \
# 0    While the patient exhibits an elevated CRP (44...                0.0
# 1    The patient's vital signs and lab values at th...                0.0
# 2    The patient exhibits some mild abnormalities s...                0.0
# 3    The patient's vital signs and lab values are l...                0.0
# 4    The patient's heart rate is slightly elevated ...                0.0
# ..                                                 ...                ...
# 985  The patient's SOFA score does not show an incr...                0.0
# 986  The patient's vital signs and lab values are l...                0.0
# 987  The patient's vital signs and lab values remai...                0.0
# 988  The patient's vital signs and lab values at th...                0.0
# 989  While the patient has an elevated CRP (245.9 m...                0.0
#
#      Inference Time  Input Tokens  Output Tokens  Thinking Tokens  \
# 0          1.665101          3980            136                0
# 1          2.021487          3979            185                0
# 2          2.870357          3977            215                0
# 3          2.321771          3978            191                0
# 4          2.105629          3978            142                0
# ..              ...           ...            ...              ...
# 985        1.753384          3963            146                0
# 986        2.108118          3963            146                0
# 987        1.829313          3963            139                0
# 988        1.818219          3963            173                0
# 989        2.144623          3963            201                0
#
#      Thinking Output      model_name    task dataset        timestamp
# 0                NaN  Gemini2p5flash  sepsis    miiv  20250624_101940
# 1                NaN  Gemini2p5flash  sepsis    miiv  20250624_101940
# 2                NaN  Gemini2p5flash  sepsis    miiv  20250624_101940
# 3                NaN  Gemini2p5flash  sepsis    miiv  20250624_101940
# 4                NaN  Gemini2p5flash  sepsis    miiv  20250624_101940
# ..               ...             ...     ...     ...              ...
# 985              NaN  Gemini2p5flash  sepsis    miiv  20250624_101940
# 986              NaN  Gemini2p5flash  sepsis    miiv  20250624_101940
# 987              NaN  Gemini2p5flash  sepsis    miiv  20250624_101940
# 988              NaN  Gemini2p5flash  sepsis    miiv  20250624_101940
# 989              NaN  Gemini2p5flash  sepsis    miiv  20250624_101940
#
# [990 rows x 15 columns]

# %%
results = []
prompting_id = "zhu_2024b_zero_shot_preprocessor"


metrics = calculate_all_metrics(
    y_true=df_mdata["Target Label"],
    y_pred=df_mdata["Predicted Probability"],
)
model_id = df_mdata["model_name"].iloc[0]
task_id = df_mdata["task"].iloc[0]
dataset = df_mdata["dataset"].iloc[0]
results.append(metrics)

run_id = df_mdata["timestamp"].iloc[0]

metrics_overall = {
    k: float(v)
    for k, v in metrics.items()
    if k
    in [
        "auroc",
        "auprc",
        "normalized_auprc",
        "specificity",
        "f1_score",
        "accuracy",
        "balanced_accuracy",
        "precision",
        "recall",
        "mcc",
        "kappa",
        "minpse",
    ]
}

output_dict = {
    "model_id": model_id,
    "task_id": task_id,
    "dataset": dataset,
    "prompting_id": prompting_id,
    "run_id": run_id,
    "metrics_summary": {"overall": metrics_overall},
}

metrics_report_path = os.path.join(
    output_path, f"{model_id}_metrics_report.json"
)
if os.path.exists(metrics_report_path):
    with open(metrics_report_path, "r") as f:
        try:
            existing_data = json.load(f)
            if isinstance(existing_data, list):
                existing_data.append(output_dict)
            else:
                existing_data = [existing_data, output_dict]
        except json.JSONDecodeError:
            existing_data = [output_dict]
    with open(metrics_report_path, "w") as f:
        json.dump(existing_data, f, indent=2)
else:
    with open(metrics_report_path, "w") as f:
        json.dump(output_dict, f, indent=2)

df_metrics = pd.DataFrame(results)
df_metrics
# Out:
#    auroc  auprc  normalized_auprc  specificity  f1_score  accuracy  \
# 0  0.442   0.02             0.788        0.741     0.022     0.726
#
#    balanced_accuracy  precision  recall   mcc  kappa  minpse
# 0              0.431      0.012    0.12 -0.05 -0.026   0.026
