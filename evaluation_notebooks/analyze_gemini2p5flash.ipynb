# %% [markdown]
# # Gemini 2.5 Flash
# ---
#
# | Parameter         | Value                                         | Description                                                                                 |
# |-------------------|-----------------------------------------------|---------------------------------------------------------------------------------------------|
# | mode              | inference                                     | Mode of operation (inference, training)                                                     |
# | model_id          | gemini-2.5-flash-preview-05-20                | Model ID                                                                                    |
# | type              | LLM                                           | Type of model (convML for conventional ML, convDL for deep learning, LLM for large language models) |
# | verbose           | 2                                             | Verbosity level                                                                             |
# | max_new_tokens    | 300                                           | Maximum number of new tokens to generate                                                    |
# | max_length        | 30000                                         | Maximum length of input sequences                                                           |
# | temperature       | 0.4                                           | Temperature for sampling (0.0 = greedy sampling)                                            |
# | thinking_budget   | 0                                             | 0 = no thinking budget, -1 = dynamic thinking budget                                        |

# %%
# Imports
import os
import sys
import pandas as pd  
import ipywidgets as widgets
from IPython.display import display

sys.path.append(r"C:\Users\janbe\Documents\GitHub Repos\pulse")
from src.eval.llm_analyzer import LLMAnalyzer
from src.eval.pulse_score import PULSEScoreCalculator

# %% [markdown]
# ## Analysis of different prompting approaches
# ---

# %%
model_id = "gemini2p5flash"
base_output_dir = (
    r"C:\Users\janbe\Documents\GitHub Repos\pulse\output_to_keep\results_benchmark"
)
model_output_dir = os.path.join(base_output_dir, "llms", model_id)
results_output_dir = os.path.join(base_output_dir, r"results_output")
results_output_jsons = os.path.join(results_output_dir, "jsons")
results_json_path = f"{model_id}_results.json"

prompt_approaches = os.listdir(model_output_dir)
for i, approach in enumerate(prompt_approaches, 1):
    print(f"{i}. {approach}")


best_prompt_approach = None
results_dict = {}
mdata_dict = {}
cost_df = pd.DataFrame()

for prompt_approach in prompt_approaches:
    if not os.path.isdir(os.path.join(model_output_dir, prompt_approach)):
        continue

    print("=" * 50)
    print(f"\nPrompting Approach {prompt_approach}\n")

    cat_files = LLMAnalyzer.categorize_files(
        [os.path.join(model_output_dir, prompt_approach)],
        verbose=False,
    )


    df_mdata = LLMAnalyzer.load_metadata(
        cat_files["metadata_files"], verbose=True
    )

    summary = LLMAnalyzer.print_approach_summary(
        df_mdata, input_token_cost=0.3, output_token_cost=2.5
    )

    # Filter for final prediction step if agent is used
    if "Step Name" in df_mdata.columns:
        df_mdata = df_mdata[df_mdata["Step Name"] == "final_prediction"].reset_index(
            drop=True
        )

    ps = PULSEScoreCalculator()
    pulse_score = ps.calculate_pulse_score_from_raw_data(
        df=df_mdata,
    )
    pulse_score["model_id"] = model_id
    pulse_score["prompting_id"] = prompt_approach
    pulse_score_temp = pulse_score["overall"]["overall_score"]
    results_dict[prompt_approach] = pulse_score
    mdata_dict[prompt_approach] = df_mdata
    cost_df[prompt_approach] = [
        summary["input_cost"].sum(),
        summary["output_cost"].sum(),
        summary["thinking_cost"].sum(),
        summary["total_cost"].sum(),
    ]

    cost_df.index = ["input_cost", "output_cost", "thinking_cost", "total_cost"]
    if best_prompt_approach is None or pulse_score_temp > best_prompt_approach[1]:

        best_prompt_approach = (prompt_approach, pulse_score_temp)

display(cost_df)
print(
    f"\nBest prompt approach: {best_prompt_approach[0]} with PULSE score: {best_prompt_approach[1]}"
)

# Save results as json. Uses pulse-result format
json_output_path = os.path.join(results_output_jsons, f"{model_id}_results.json")
final_json = LLMAnalyzer.save_results_dict_as_json(results_dict, json_output_path)
# Out:
# 1. clinical_workflow_agent_preprocessor
# 2. collaborative_reasoning_agent_preprocessor
# 3. hybrid_reasoning_agent_preprocessor
# 4. liu_2023_few_shot_preprocessor
# 5. sarvari_2024_aggregation_preprocessor
# 6. zhu_2024a_cot_preprocessor
# 7. zhu_2024b_one_shot_preprocessor
# 8. zhu_2024b_zero_shot_preprocessor
# 9. zhu_2024c_categorization_summary_agent_preprocessor
# ==================================================
#
# Prompting Approach clinical_workflow_agent_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemini2p5flash, Task: aki, Dataset: eicu, Timestamp: 20250703_194029
# Model Name: Gemini2p5flash, Task: aki, Dataset: hirid, Timestamp: 20250703_194029
# Model Name: Gemini2p5flash, Task: aki, Dataset: miiv, Timestamp: 20250703_122517
# Model Name: Gemini2p5flash, Task: mortality, Dataset: eicu, Timestamp: 20250703_194029
# Model Name: Gemini2p5flash, Task: mortality, Dataset: hirid, Timestamp: 20250703_194029
# Model Name: Gemini2p5flash, Task: mortality, Dataset: miiv, Timestamp: 20250703_133416
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: eicu, Timestamp: 20250703_194029
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: hirid, Timestamp: 20250703_194029
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: miiv, Timestamp: 20250703_133416
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 43038
# Total Input Tokens: 41279869
# Total Output Tokens: 7067176
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $30.05
# =================
# Preparing data for Gemini2p5flash PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 526.0
#   Probability range: [0.000, 1.000]
#   Probability mean: 0.237
#   Probability std: 0.329
#   Probability median: 0.050
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 206.0
#   Probability range: [0.050, 0.980]
#   Probability mean: 0.613
#   Probability std: 0.269
#   Probability median: 0.750
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2370.0
#   Probability range: [0.020, 0.990]
#   Probability mean: 0.763
#   Probability std: 0.232
#   Probability median: 0.850
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'diagnosis' 'not-mortality' 'mortality' 'not-diagnosis'
#  'sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemini2p5flash!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  47.471942
# 1        overall_aki  49.911223
# 2       overall_eicu  49.146942
# 3  overall_mortality  52.525559
# 4      overall_hirid  45.817876
# 5     overall_sepsis  39.979045
# 6       overall_miiv  47.451009
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           53.925536  0.406159  0.627062  0.597853  0.990854
# aki_hirid          44.211325  0.206148  0.580374  0.550322  0.989817
# aki_miiv           51.596808  0.358782  0.606241  0.591005  0.993394
# mortality_eicu     51.448429  0.226934  0.774194  0.545299  0.997500
# mortality_hirid    44.497272  0.250034  0.623085  0.466561  0.996000
# mortality_miiv     61.630977  0.448759  0.792614  0.609629  0.999000
# sepsis_eicu        42.066862  0.061203  0.645915  0.551067  0.999898
# sepsis_hirid       48.745030  0.234730  0.705411  0.521336  0.999897
# sepsis_miiv        29.125243  0.017372  0.367772  0.483199  0.999545
# ==================================================
#
# Prompting Approach collaborative_reasoning_agent_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemini2p5flash, Task: aki, Dataset: eicu, Timestamp: 20250702_080324
# Model Name: Gemini2p5flash, Task: aki, Dataset: hirid, Timestamp: 20250702_080324
# Model Name: Gemini2p5flash, Task: aki, Dataset: miiv, Timestamp: 20250703_080308
# Model Name: Gemini2p5flash, Task: mortality, Dataset: eicu, Timestamp: 20250702_080324
# Model Name: Gemini2p5flash, Task: mortality, Dataset: hirid, Timestamp: 20250702_080324
# Model Name: Gemini2p5flash, Task: mortality, Dataset: miiv, Timestamp: 20250701_170957
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: eicu, Timestamp: 20250702_080324
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: hirid, Timestamp: 20250702_080324
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: miiv, Timestamp: 20250701_170957
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 30945
# Total Input Tokens: 29737152
# Total Output Tokens: 5012490
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $21.45
# =================
# Preparing data for Gemini2p5flash PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 1146.0
#   Probability range: [0.100, 0.980]
#   Probability mean: 0.467
#   Probability std: 0.281
#   Probability median: 0.350
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 293.0
#   Probability range: [0.250, 0.950]
#   Probability mean: 0.772
#   Probability std: 0.115
#   Probability median: 0.800
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2870.0
#   Probability range: [0.250, 0.980]
#   Probability mean: 0.791
#   Probability std: 0.100
#   Probability median: 0.800
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'diagnosis' 'mortality' 'not-mortality' 'not-diagnosis'
#  'sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemini2p5flash!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  48.008235
# 1        overall_aki  50.877656
# 2       overall_eicu  45.812733
# 3  overall_mortality  53.001650
# 4      overall_hirid  47.359738
# 5     overall_sepsis  40.145398
# 6       overall_miiv  50.852233
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc  ccf
# aki_eicu           54.548790  0.425029  0.615959  0.594006  1.0
# aki_hirid          46.686273  0.250786  0.601313  0.546089  1.0
# aki_miiv           51.397905  0.378150  0.617407  0.545428  1.0
# mortality_eicu     45.341553  0.135880  0.702765  0.519597  1.0
# mortality_hirid    46.609612  0.246086  0.651175  0.500000  1.0
# mortality_miiv     67.053784  0.647381  0.825758  0.542359  1.0
# sepsis_eicu        37.547856  0.050658  0.563009  0.508731  1.0
# sepsis_hirid       48.783328  0.237403  0.719040  0.506491  1.0
# sepsis_miiv        34.105008  0.022516  0.480663  0.514709  1.0
# ==================================================
#
# Prompting Approach hybrid_reasoning_agent_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemini2p5flash, Task: aki, Dataset: eicu, Timestamp: 20250704_142727
# Model Name: Gemini2p5flash, Task: aki, Dataset: hirid, Timestamp: 20250704_142727
# Model Name: Gemini2p5flash, Task: aki, Dataset: miiv, Timestamp: 20250704_142727
# Model Name: Gemini2p5flash, Task: mortality, Dataset: eicu, Timestamp: 20250704_142727
# Model Name: Gemini2p5flash, Task: mortality, Dataset: hirid, Timestamp: 20250704_142727
# Model Name: Gemini2p5flash, Task: mortality, Dataset: miiv, Timestamp: 20250704_142727
# Fixed csv file with path C:\Users\janbe\Documents\GitHub Repos\pulse\output_to_keep\results_benchmark\llms\gemini2p5flash\hybrid_reasoning_agent_preprocessor\Gemini2p5flash_sepsis_eicu_20250704_142727_metadata.csv and replaced old one.
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: eicu, Timestamp: 20250704_142727
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: hirid, Timestamp: 20250704_142727
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: miiv, Timestamp: 20250704_142727
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 26823
# Total Input Tokens: 17713090
# Total Output Tokens: 3896533
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $15.06
# =================
# Preparing data for Gemini2p5flash PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 588.0
#   Probability range: [0.020, 1.000]
#   Probability mean: 0.243
#   Probability std: 0.280
#   Probability median: 0.100
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 35.0
#   Probability range: [0.020, 1.000]
#   Probability mean: 0.181
#   Probability std: 0.283
#   Probability median: 0.050
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 313.0
#   Probability range: [0.000, 1.000]
#   Probability mean: 0.130
#   Probability std: 0.227
#   Probability median: 0.040
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'diagnosis' 'not-mortality' 'mortality' 'not-diagnosis'
#  'not-sepsis' 'sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemini2p5flash!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  51.098551
# 1        overall_aki  59.848806
# 2       overall_eicu  46.887328
# 3  overall_mortality  51.545250
# 4      overall_hirid  53.024527
# 5     overall_sepsis  41.901596
# 6       overall_miiv  53.383797
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           61.460903  0.499439  0.712497  0.634548  0.998252
# aki_hirid          54.372069  0.298909  0.747476  0.607872  0.985031
# aki_miiv           63.713445  0.517538  0.748622  0.646778  0.999055
# mortality_eicu     43.985643  0.118367  0.729647  0.557606  0.937000
# mortality_hirid    50.037473  0.202311  0.744127  0.613292  0.960700
# mortality_miiv     60.612633  0.357878  0.809659  0.690561  0.977500
# sepsis_eicu        35.215438  0.048858  0.525119  0.480771  0.997959
# sepsis_hirid       54.664037  0.217005  0.788145  0.634921  0.998297
# sepsis_miiv        35.825313  0.031935  0.551358  0.488742  0.998869
# ==================================================
#
# Prompting Approach liu_2023_few_shot_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemini2p5flash, Task: aki, Dataset: eicu, Timestamp: 20250623_140022
# Model Name: Gemini2p5flash, Task: aki, Dataset: hirid, Timestamp: 20250623_140022
# Model Name: Gemini2p5flash, Task: aki, Dataset: miiv, Timestamp: 20250623_140022
# Model Name: Gemini2p5flash, Task: mortality, Dataset: eicu, Timestamp: 20250623_140022
# Model Name: Gemini2p5flash, Task: mortality, Dataset: hirid, Timestamp: 20250623_140022
# Model Name: Gemini2p5flash, Task: mortality, Dataset: miiv, Timestamp: 20250623_140022
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: eicu, Timestamp: 20250623_140022
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: hirid, Timestamp: 20250623_140022
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: miiv, Timestamp: 20250623_140022
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 64886076
# Total Output Tokens: 823214
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $21.52
# =================
# Preparing data for Gemini2p5flash PULSE score calculation...
# Model Type: LLM
#
# ⚠️ Wrongly labled predictions: 1
# Wrongly labeled predictions:
#   - error: 1 occurrences
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 620.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.261
#   Probability std: 0.331
#   Probability median: 0.100
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 150.0
#   Probability range: [0.100, 0.950]
#   Probability mean: 0.456
#   Probability std: 0.330
#   Probability median: 0.475
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 1135.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.415
#   Probability std: 0.338
#   Probability median: 0.200
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['aki' 'not-aki' 'mortality' 'not-mortality' 'sepsis' 'not-sepsis' 'error'
#  'diagnosis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemini2p5flash!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  53.606298
# 1        overall_aki  54.377861
# 2       overall_eicu  53.041132
# 3  overall_mortality  61.198189
# 4      overall_hirid  53.590651
# 5     overall_sepsis  45.242844
# 6       overall_miiv  54.187110
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc     ccf
# aki_eicu           59.057306  0.541327  0.627084  0.602933  1.0000
# aki_hirid          50.011670  0.301763  0.628553  0.567979  1.0000
# aki_miiv           54.064606  0.417566  0.600217  0.602288  1.0000
# mortality_eicu     55.207662  0.388841  0.725038  0.542637  1.0000
# mortality_hirid    55.758255  0.414740  0.695097  0.568514  0.9965
# mortality_miiv     72.628650  0.627842  0.876894  0.675657  1.0000
# sepsis_eicu        44.858428  0.067423  0.687802  0.586352  1.0000
# sepsis_hirid       55.002028  0.281911  0.760794  0.605669  1.0000
# sepsis_miiv        35.868075  0.024961  0.546114  0.500664  1.0000
# ==================================================
#
# Prompting Approach sarvari_2024_aggregation_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemini2p5flash, Task: aki, Dataset: eicu, Timestamp: 20250622_111935
# Model Name: Gemini2p5flash, Task: aki, Dataset: hirid, Timestamp: 20250623_083510
# Model Name: Gemini2p5flash, Task: aki, Dataset: miiv, Timestamp: 20250623_113400
# Model Name: Gemini2p5flash, Task: mortality, Dataset: eicu, Timestamp: 20250617_215555
# Model Name: Gemini2p5flash, Task: mortality, Dataset: hirid, Timestamp: 20250623_083510
# Model Name: Gemini2p5flash, Task: mortality, Dataset: miiv, Timestamp: 20250623_083510
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: eicu, Timestamp: 20250622_111935
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: hirid, Timestamp: 20250623_083510
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: miiv, Timestamp: 20250623_083510
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 13606360
# Total Output Tokens: 1088173
# Total Thinking Tokens: 0.0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $6.80
# =================
# Preparing data for Gemini2p5flash PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 205.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.139
#   Probability std: 0.216
#   Probability median: 0.080
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 232.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.651
#   Probability std: 0.284
#   Probability median: 0.750
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 796.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.321
#   Probability std: 0.324
#   Probability median: 0.150
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'mortality' 'not-mortality' 'sepsis' 'not-diagnosis'
#  'diagnosis' 'not-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemini2p5flash!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  48.761957
# 1        overall_aki  50.761728
# 2       overall_eicu  44.384547
# 3  overall_mortality  53.502914
# 4      overall_hirid  53.452432
# 5     overall_sepsis  42.021228
# 6       overall_miiv  48.448892
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc  ccf
# aki_eicu           50.514056  0.411390  0.557829  0.544995  1.0
# aki_hirid          48.811069  0.286445  0.574711  0.599791  1.0
# aki_miiv           52.960060  0.404918  0.576786  0.604818  1.0
# mortality_eicu     46.334853  0.283448  0.575269  0.529330  1.0
# mortality_hirid    55.349137  0.493207  0.638917  0.529090  1.0
# mortality_miiv     58.824752  0.492273  0.698390  0.574496  1.0
# sepsis_eicu        36.304732  0.049020  0.559143  0.477510  1.0
# sepsis_hirid       56.197090  0.267319  0.779721  0.636611  1.0
# sepsis_miiv        33.561863  0.022322  0.489036  0.490795  1.0
# ==================================================
#
# Prompting Approach zhu_2024a_cot_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemini2p5flash, Task: aki, Dataset: eicu, Timestamp: 20250624_172337
# Model Name: Gemini2p5flash, Task: aki, Dataset: hirid, Timestamp: 20250624_172337
# Model Name: Gemini2p5flash, Task: aki, Dataset: miiv, Timestamp: 20250624_172337
# Model Name: Gemini2p5flash, Task: mortality, Dataset: eicu, Timestamp: 20250624_172337
# Model Name: Gemini2p5flash, Task: mortality, Dataset: hirid, Timestamp: 20250624_172337
# Model Name: Gemini2p5flash, Task: mortality, Dataset: miiv, Timestamp: 20250624_172337
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: eicu, Timestamp: 20250624_172337
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: hirid, Timestamp: 20250624_172337
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: miiv, Timestamp: 20250624_172337
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 29581035
# Total Output Tokens: 1095684
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $11.61
# =================
# Preparing data for Gemini2p5flash PULSE score calculation...
# Model Type: LLM
#
# ⚠️ Wrongly labled predictions: 46
# Wrongly labeled predictions:
#   - error: 43 occurrences
#   - unknown: 3 occurrences
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 323.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.183
#   Probability std: 0.253
#   Probability median: 0.100
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 80.0
#   Probability range: [0.100, 0.850]
#   Probability mean: 0.324
#   Probability std: 0.269
#   Probability median: 0.200
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 618.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.320
#   Probability std: 0.266
#   Probability median: 0.200
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'unknown' 'not-mortality' 'mortality' 'sepsis'
#  'not-diagnosis' 'diagnosis' 'error' 'not-sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemini2p5flash!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  49.651638
# 1        overall_aki  52.738898
# 2       overall_eicu  48.078650
# 3  overall_mortality  56.302250
# 4      overall_hirid  51.596164
# 5     overall_sepsis  39.913766
# 6       overall_miiv  49.280101
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           54.039507  0.454616  0.598933  0.568452  0.998984
# aki_hirid          49.234402  0.314521  0.591512  0.569423  0.999491
# aki_miiv           54.942786  0.409672  0.607730  0.628485  1.000000
# mortality_eicu     52.792144  0.241944  0.761905  0.578386  1.000000
# mortality_hirid    55.187143  0.311768  0.706844  0.634499  1.000000
# mortality_miiv     60.927465  0.374517  0.766572  0.684457  1.000000
# sepsis_eicu        37.404300  0.048146  0.575428  0.494893  1.000000
# sepsis_hirid       50.366947  0.176426  0.731057  0.600588  1.000000
# sepsis_miiv        31.970051  0.021273  0.449916  0.482964  1.000000
# ==================================================
#
# Prompting Approach zhu_2024b_one_shot_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemini2p5flash, Task: aki, Dataset: eicu, Timestamp: 20250625_104921
# Model Name: Gemini2p5flash, Task: aki, Dataset: hirid, Timestamp: 20250625_104921
# Model Name: Gemini2p5flash, Task: aki, Dataset: miiv, Timestamp: 20250625_104921
# Model Name: Gemini2p5flash, Task: mortality, Dataset: eicu, Timestamp: 20250625_104921
# Model Name: Gemini2p5flash, Task: mortality, Dataset: hirid, Timestamp: 20250625_104921
# Model Name: Gemini2p5flash, Task: mortality, Dataset: miiv, Timestamp: 20250625_104921
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: eicu, Timestamp: 20250625_104921
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: hirid, Timestamp: 20250625_104921
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: miiv, Timestamp: 20250625_104921
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 43360101
# Total Output Tokens: 888058
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $15.23
# =================
# Preparing data for Gemini2p5flash PULSE score calculation...
# Model Type: LLM
#
# ⚠️ Wrongly labled predictions: 3
# Wrongly labeled predictions:
#   - error: 3 occurrences
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 443.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.214
#   Probability std: 0.296
#   Probability median: 0.100
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 151.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.447
#   Probability std: 0.330
#   Probability median: 0.650
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 1130.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.451
#   Probability std: 0.319
#   Probability median: 0.300
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'error' 'mortality' 'not-mortality' 'sepsis' 'not-sepsis'
#  'not-diagnosis' 'diagnosis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemini2p5flash!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  53.774499
# 1        overall_aki  57.565281
# 2       overall_eicu  56.048146
# 3  overall_mortality  61.258041
# 4      overall_hirid  53.888723
# 5     overall_sepsis  42.500175
# 6       overall_miiv  51.386628
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc  ccf
# aki_eicu           62.534127  0.569672  0.664294  0.641566  1.0
# aki_hirid          51.821324  0.333913  0.626906  0.591597  1.0
# aki_miiv           58.340391  0.460958  0.640178  0.647144  1.0
# mortality_eicu     61.097331  0.415287  0.807988  0.609684  1.0
# mortality_hirid    57.643410  0.316011  0.761491  0.649583  1.0
# mortality_miiv     65.033381  0.509840  0.770360  0.670200  1.0
# sepsis_eicu        44.512979  0.072422  0.674067  0.584672  1.0
# sepsis_hirid       52.201434  0.209643  0.742363  0.611330  1.0
# sepsis_miiv        30.786112  0.019624  0.429367  0.469689  1.0
# ==================================================
#
# Prompting Approach zhu_2024b_zero_shot_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemini2p5flash, Task: aki, Dataset: eicu, Timestamp: 20250619_150123
# Model Name: Gemini2p5flash, Task: aki, Dataset: hirid, Timestamp: 20250624_101940
# Model Name: Gemini2p5flash, Task: aki, Dataset: miiv, Timestamp: 20250624_101940
# Model Name: Gemini2p5flash, Task: mortality, Dataset: eicu, Timestamp: 20250617_214747
# Model Name: Gemini2p5flash, Task: mortality, Dataset: hirid, Timestamp: 20250624_101940
# Model Name: Gemini2p5flash, Task: mortality, Dataset: miiv, Timestamp: 20250624_101940
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: eicu, Timestamp: 20250619_150123
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: hirid, Timestamp: 20250624_101940
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: miiv, Timestamp: 20250624_101940
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 6189
# Total Input Tokens: 26372683
# Total Output Tokens: 1033221
# Total Thinking Tokens: 0.0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $10.49
# =================
# Preparing data for Gemini2p5flash PULSE score calculation...
# Model Type: LLM
#
# ⚠️ Wrongly labled predictions: 6
# Wrongly labeled predictions:
#   - error: 6 occurrences
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 410.0
#   Probability range: [0.050, 1.000]
#   Probability mean: 0.195
#   Probability std: 0.296
#   Probability median: 0.100
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 130.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.407
#   Probability std: 0.319
#   Probability median: 0.200
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 880.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.375
#   Probability std: 0.310
#   Probability median: 0.200
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['not-aki' 'aki' 'error' 'not-mortality' 'mortality' 'sepsis'
#  'not-diagnosis' 'diagnosis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemini2p5flash!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  51.665638
# 1        overall_aki  54.123539
# 2       overall_eicu  52.829056
# 3  overall_mortality  59.779209
# 4      overall_hirid  50.390820
# 5     overall_sepsis  41.094166
# 6       overall_miiv  51.777038
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc  ccf
# aki_eicu           57.253456  0.498778  0.608904  0.608822  1.0
# aki_hirid          47.589886  0.236385  0.605562  0.582519  1.0
# aki_miiv           57.527274  0.453233  0.642454  0.628518  1.0
# mortality_eicu     61.458704  0.389201  0.830261  0.624013  1.0
# mortality_hirid    51.481541  0.336437  0.636874  0.569479  1.0
# mortality_miiv     66.397382  0.552534  0.805871  0.634412  1.0
# sepsis_eicu        39.775009  0.057063  0.613259  0.519247  1.0
# sepsis_hirid       52.101033  0.197977  0.746231  0.615947  1.0
# sepsis_miiv        31.406457  0.019951  0.442326  0.475038  1.0
# ==================================================
#
# Prompting Approach zhu_2024c_categorization_summary_agent_preprocessor
#
# Extracting metadata from files:
# Model Name: Gemini2p5flash, Task: aki, Dataset: eicu, Timestamp: 20250701_090405
# Model Name: Gemini2p5flash, Task: aki, Dataset: hirid, Timestamp: 20250701_090405
# Model Name: Gemini2p5flash, Task: aki, Dataset: miiv, Timestamp: 20250630_123648
# Model Name: Gemini2p5flash, Task: mortality, Dataset: eicu, Timestamp: 20250701_090405
# Model Name: Gemini2p5flash, Task: mortality, Dataset: hirid, Timestamp: 20250701_090405
# Model Name: Gemini2p5flash, Task: mortality, Dataset: miiv, Timestamp: 20250701_152823
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: eicu, Timestamp: 20250701_090405
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: hirid, Timestamp: 20250701_090405
# Model Name: Gemini2p5flash, Task: sepsis, Dataset: miiv, Timestamp: 20250701_152823
#
# =====Overall=====:
# Number of Samples: 6189
# Number of Requests: 12378
# Total Input Tokens: 9114235
# Total Output Tokens: 2187384
# Total Thinking Tokens: 0
# Average Thinking Tokens: 0.00
# Total Cost (USD): $8.20
# =================
# Preparing data for Gemini2p5flash PULSE score calculation...
# Model Type: LLM
# ✓ No invalid predictions detected
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950/2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 1286.0
#   Probability range: [0.000, 0.950]
#   Probability mean: 0.526
#   Probability std: 0.269
#   Probability median: 0.400
#
# MORTALITY:
#   Total samples: 300/300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 300.0
#   Probability range: [0.750, 0.950]
#   Probability mean: 0.880
#   Probability std: 0.050
#   Probability median: 0.850
#
# SEPSIS:
#   Total samples: 2939/2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2692.0
#   Probability range: [0.200, 0.950]
#   Probability mean: 0.766
#   Probability std: 0.133
#   Probability median: 0.750
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: object, values: ['aki' 'diagnosis' 'not-aki' 'mortality' 'not-diagnosis' 'sepsis']
#
# Data source information:
#   • Predictions from explicit prediction column
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
#
# ✅ PULSE scores calculated successfully for Gemini2p5flash!
# PULSE SCORE DETAILED REPORT
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# OVERALL SCORES
# --------------------------------------------------
#               Metric      Value
# 0      overall_score  46.124086
# 1        overall_aki  50.222023
# 2       overall_eicu  43.165032
# 3  overall_mortality  49.112047
# 4      overall_hirid  49.017805
# 5     overall_sepsis  39.038188
# 6       overall_miiv  46.189421
#
# TASK DATASET SCORES
# --------------------------------------------------
#                  pulse_score     auprc     auroc       mcc       ccf
# aki_eicu           53.361785  0.434567  0.599874  0.570327  0.996900
# aki_hirid          45.627433  0.264857  0.573722  0.533075  0.996283
# aki_miiv           51.676851  0.380252  0.606880  0.566613  0.996850
# mortality_eicu     40.168559  0.209758  0.492320  0.500000  1.000000
# mortality_hirid    55.203501  0.476885  0.680797  0.500000  1.000000
# mortality_miiv     51.964079  0.418893  0.640625  0.500000  1.000000
# sepsis_eicu        35.964752  0.043013  0.506134  0.539288  0.986480
# sepsis_hirid       46.222480  0.203636  0.668366  0.524162  0.991950
# sepsis_miiv        34.927332  0.024517  0.519668  0.518764  0.981212
#                clinical_workflow_agent_preprocessor  \
# input_cost                                12.383961
# output_cost                               17.667940
# thinking_cost                              0.000000
# total_cost                                30.051901
#
#                collaborative_reasoning_agent_preprocessor  \
# input_cost                                       8.921146
# output_cost                                     12.531225
# thinking_cost                                    0.000000
# total_cost                                      21.452371
#
#                hybrid_reasoning_agent_preprocessor  \
# input_cost                                5.313927
# output_cost                               9.741333
# thinking_cost                             0.000000
# total_cost                               15.055260
#
#                liu_2023_few_shot_preprocessor  \
# input_cost                          19.465823
# output_cost                          2.058035
# thinking_cost                        0.000000
# total_cost                          21.523858
#
#                sarvari_2024_aggregation_preprocessor  \
# input_cost                                  4.081908
# output_cost                                 2.720432
# thinking_cost                               0.000000
# total_cost                                  6.802340
#
#                zhu_2024a_cot_preprocessor  zhu_2024b_one_shot_preprocessor  \
# input_cost                        8.87431                        13.008030
# output_cost                       2.73921                         2.220145
# thinking_cost                     0.00000                         0.000000
# total_cost                       11.61352                        15.228175
#
#                zhu_2024b_zero_shot_preprocessor  \
# input_cost                             7.911805
# output_cost                            2.583052
# thinking_cost                          0.000000
# total_cost                            10.494857
#
#                zhu_2024c_categorization_summary_agent_preprocessor
# input_cost                                              2.734271
# output_cost                                             5.468460
# thinking_cost                                           0.000000
# total_cost                                              8.202730
# Best prompt approach: zhu_2024b_one_shot_preprocessor with PULSE score: 53.77449874260853
# Saved 81 result entries to C:\Users\janbe\Documents\GitHub Repos\pulse\output_to_keep\results_benchmark\results_output\jsons\gemini2p5flash_results.json

# %% [markdown]
# Summary Metrics of all Prompting Appraches

# %%
df_results = LLMAnalyzer.load_metrics_from_prompt_approaches(
    model_output_dir, prompt_approaches
)

LLMAnalyzer.plot_metrics(
    df_results, group=["prompting_id"], title_prefix="Gemini 2.5 Flash - "
)
# Out:
# C:\Users\janbe\Documents\GitHub Repos\pulse\src\eval\llm_analyzer.py:951: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = plot_df.groupby(["Group", "Metric"], as_index=False).agg(

# %% [markdown]
# Metrics per Prompt and Task

# %%
LLMAnalyzer.plot_metrics(
    df_results,
    group=["task_id", "prompting_id"],
    title_prefix="Gemini 2.5 Flash - ",
)
# Out:
# C:\Users\janbe\Documents\GitHub Repos\pulse\src\eval\llm_analyzer.py:951: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = plot_df.groupby(["Group", "Metric"], as_index=False).agg(

# %% [markdown]
# ---
