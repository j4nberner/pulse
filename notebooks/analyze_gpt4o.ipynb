# %% [markdown]
# # OpenAi GPT4o - Evaluation

# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt

sys.path.append(r"C:\Users\janbe\Documents\GitHub Repos\pulse")
from src.eval.llm_analyzer import LLMAnalyzer

# %%
base_output_dir = r"C:\Users\janbe\Documents\GitHub Repos\pulse\output_to_keep\results_benchmark\llms\gpt4o"
prompt_approaches = os.listdir(base_output_dir)

# %%
from src.eval.pulse_score import PULSEScoreCalculator

best_prompt_approach = None
results_dict = {}

for prompt_approach in prompt_approaches:
    if not os.path.isdir(os.path.join(base_output_dir, prompt_approach)):
        continue
    print(f"Processing {prompt_approach}...")
    cat_files = LLMAnalyzer.categorize_files(
        [os.path.join(base_output_dir, prompt_approach)],
        verbose=False,
    )
    df_mdata = LLMAnalyzer.load_metadata(cat_files["metadata_files"])
    if "Step Name" in df_mdata.columns:
        df_mdata = df_mdata[df_mdata["Step Name"] == "final_prediction"]

    ps = PULSEScoreCalculator()
    pulse_score = ps.calculate_pulse_score_from_raw_data(
        df=df_mdata,
    )
    pulse_score_temp = pulse_score["overall"]["pulse_score"]
    results_dict[prompt_approach] = pulse_score["overall"]

    if best_prompt_approach is None or pulse_score_temp > best_prompt_approach[1]:
        best_prompt_approach = (prompt_approach, pulse_score_temp)

print(
    f"Best prompt approach: {best_prompt_approach[0]} with PULSE score: {best_prompt_approach[1]}"
)
# Out:
# Processing sarvari_2024_aggregation_preprocessor...
# Model Name: GPT4o, Task: aki, Dataset: eicu, Timestamp: 20250623_084058
# Model Name: GPT4o, Task: aki, Dataset: hirid, Timestamp: 20250623_084058
# Model Name: GPT4o, Task: aki, Dataset: miiv, Timestamp: 20250623_084058
# Model Name: GPT4o, Task: mortality, Dataset: eicu, Timestamp: 20250623_084058
# Model Name: GPT4o, Task: mortality, Dataset: hirid, Timestamp: 20250623_084058
# Model Name: GPT4o, Task: mortality, Dataset: miiv, Timestamp: 20250623_084058
# Model Name: GPT4o, Task: sepsis, Dataset: eicu, Timestamp: 20250623_084058
# Model Name: GPT4o, Task: sepsis, Dataset: hirid, Timestamp: 20250623_084058
# Model Name: GPT4o, Task: sepsis, Dataset: miiv, Timestamp: 20250623_084058
# Preparing data for GPT4o PULSE score calculation...
# ==================================================
# DATA VERIFICATION FOR PULSE SCORE
# ==================================================
# Model Type: LLM
# ✓ Required columns present: True
# ✓ Target Label is binary: True
# ✓ Predicted Diagnosis is binary: True
# ✓ Predicted Probability in [0,1]: True
# ✓ No invalid predictions detected
#
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 332.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.150
#
# MORTALITY:
#   Total samples: 300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 79.0
#   Probability range: [0.100, 0.950]
#   Probability mean: 0.399
#
# SEPSIS:
#   Total samples: 2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 497.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.288
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: float64, values: [0. 1.]
#   Predicted Probability: float64, values: [0.05 0.85 0.15 0.92 0.9 ]
#
# Data source information:
#   • Predictions derived from probabilities (threshold = 0.5)
#   • Total samples: 6189
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
# Calculating PULSE scores...
# ✅ PULSE scores calculated successfully for GPT4o!
# ============================================================
# PULSE SCORE DETAILED REPORT
# ============================================================
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# Task: AKI
# ------------------------------
# PULSE Score: 53.91
# Interpretation: Moderate performance with confidence issues
# Base Score: 0.539
# CCF: 1.000
# AUPRC: 0.412
# AUROC: 0.594
# MCC (normalized): 0.610
# Average Penalty: 0.000
# Problematic Predictions: 0 (inconsistent or invalid)
#
# Task: MORTALITY
# ------------------------------
# PULSE Score: 57.17
# Interpretation: Moderate performance with confidence issues
# Base Score: 0.572
# CCF: 1.000
# AUPRC: 0.336
# AUROC: 0.737
# MCC (normalized): 0.640
# Average Penalty: 0.000
# Problematic Predictions: 0 (inconsistent or invalid)
#
# Task: SEPSIS
# ------------------------------
# PULSE Score: 39.49
# Interpretation: Poor performance with significant confidence problems
# Base Score: 0.395
# CCF: 1.000
# AUPRC: 0.063
# AUROC: 0.592
# MCC (normalized): 0.526
# Average Penalty: 0.000
# Problematic Predictions: 0 (inconsistent or invalid)
#
# OVERALL PULSE SCORE
# ==============================
# Score: 50.19
# Interpretation: Moderate performance with confidence issues
# Task Weights: {'sepsis': 0.33, 'mortality': 0.33, 'aki': 0.33}
# ================================================================================
# 🔍 KEY INSIGHTS - PULSE SCORE ANALYSIS
# ================================================================================
# 🎯 FINAL PULSE SCORE: 50.19/100
# 📈 Performance Category: Moderate performance with confidence issues
#
# 📊 AKI Analysis:
#    • Base performance: 53.9/100
#    • Final PULSE score: 53.9/100
#    • Penalty impact: -0.0 points
#    • Problematic predictions: 0 (inconsistent or invalid)
#
# 📊 MORTALITY Analysis:
#    • Base performance: 57.2/100
#    • Final PULSE score: 57.2/100
#    • Penalty impact: -0.0 points
#    • Problematic predictions: 0 (inconsistent or invalid)
#
# 📊 SEPSIS Analysis:
#    • Base performance: 39.5/100
#    • Final PULSE score: 39.5/100
#    • Penalty impact: -0.0 points
#    • Problematic predictions: 0 (inconsistent or invalid)
#
# ⚠️  PREDICTION QUALITY:
#    • Average penalty impact: -0.0 points per task
#    • This indicates minimal issues with prediction quality
#    • Issues include: confidence-prediction inconsistency & invalid task understanding
#
# 🔬 CLINICAL IMPACT:
#    • Sepsis prediction: 39.5/100
#    • Mortality prediction: 57.2/100
#    • Aki prediction: 53.9/100
# Processing zhu_2024b_zero_shot_preprocessor...
# Model Name: GPT4o, Task: aki, Dataset: eicu, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: aki, Dataset: hirid, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: aki, Dataset: miiv, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: mortality, Dataset: eicu, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: mortality, Dataset: hirid, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: mortality, Dataset: miiv, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: sepsis, Dataset: eicu, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: sepsis, Dataset: hirid, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: sepsis, Dataset: miiv, Timestamp: 20250622_142837
# Preparing data for GPT4o PULSE score calculation...
# ==================================================
# DATA VERIFICATION FOR PULSE SCORE
# ==================================================
# Model Type: LLM
# ✓ Required columns present: True
# ✓ Target Label is binary: True
# ✓ Predicted Diagnosis is binary: True
# ✓ Predicted Probability in [0,1]: True
# ✓ No invalid predictions detected
#
# ✅ Data format is correct for PULSE calculation!
#
# Data distribution by task:
#
# AKI:
#   Total samples: 2950
#   Positive labels: 693
#   Valid predictions: 2950
#   Positive predictions: 636.0
#   Probability range: [0.050, 0.950]
#   Probability mean: 0.256
#
# MORTALITY:
#   Total samples: 300
#   Positive labels: 30
#   Valid predictions: 300
#   Positive predictions: 235.0
#   Probability range: [0.200, 0.950]
#   Probability mean: 0.729
#
# SEPSIS:
#   Total samples: 2939
#   Positive labels: 145
#   Valid predictions: 2939
#   Positive predictions: 2065.0
#   Probability range: [0.100, 0.950]
#   Probability mean: 0.660
#
# Data types and unique values:
#   Target Label: int64, values: [0 1]
#   Predicted Diagnosis: float64, values: [0. 1.]
#   Predicted Probability: float64, values: [0.15 0.1  0.85 0.92 0.95]
#
# Data source information:
#   • Predictions derived from probabilities (threshold = 0.5)
#   • Total samples: 6189
#   • Tasks: aki, mortality, sepsis
#   • Datasets: eicu, hirid, miiv
# Calculating PULSE scores...
# ✅ PULSE scores calculated successfully for GPT4o!
# ============================================================
# PULSE SCORE DETAILED REPORT
# ============================================================
# Model Type: LLM
# Weights: AUPRC=0.33, AUROC=0.33, MCC=0.34
#
# Task: AKI
# ------------------------------
# PULSE Score: 53.50
# Interpretation: Moderate performance with confidence issues
# Base Score: 0.535
# CCF: 1.000
# AUPRC: 0.392
# AUROC: 0.623
# MCC (normalized): 0.588
# Average Penalty: 0.000
# Problematic Predictions: 0 (inconsistent or invalid)
#
# Task: MORTALITY
# ------------------------------
# PULSE Score: 57.07
# Interpretation: Moderate performance with confidence issues
# Base Score: 0.571
# CCF: 1.000
# AUPRC: 0.411
# AUROC: 0.741
# MCC (normalized): 0.561
# Average Penalty: 0.000
# Problematic Predictions: 0 (inconsistent or invalid)
#
# Task: SEPSIS
# ------------------------------
# PULSE Score: 41.33
# Interpretation: Moderate performance with confidence issues
# Base Score: 0.413
# CCF: 1.000
# AUPRC: 0.094
# AUROC: 0.615
# MCC (normalized): 0.528
# Average Penalty: 0.000
# Problematic Predictions: 0 (inconsistent or invalid)
#
# OVERALL PULSE SCORE
# ==============================
# Score: 50.63
# Interpretation: Moderate performance with confidence issues
# Task Weights: {'sepsis': 0.33, 'mortality': 0.33, 'aki': 0.33}
# ================================================================================
# 🔍 KEY INSIGHTS - PULSE SCORE ANALYSIS
# ================================================================================
# 🎯 FINAL PULSE SCORE: 50.63/100
# 📈 Performance Category: Moderate performance with confidence issues
#
# 📊 AKI Analysis:
#    • Base performance: 53.5/100
#    • Final PULSE score: 53.5/100
#    • Penalty impact: -0.0 points
#    • Problematic predictions: 0 (inconsistent or invalid)
#
# 📊 MORTALITY Analysis:
#    • Base performance: 57.1/100
#    • Final PULSE score: 57.1/100
#    • Penalty impact: -0.0 points
#    • Problematic predictions: 0 (inconsistent or invalid)
#
# 📊 SEPSIS Analysis:
#    • Base performance: 41.3/100
#    • Final PULSE score: 41.3/100
#    • Penalty impact: -0.0 points
#    • Problematic predictions: 0 (inconsistent or invalid)
#
# ⚠️  PREDICTION QUALITY:
#    • Average penalty impact: -0.0 points per task
#    • This indicates minimal issues with prediction quality
#    • Issues include: confidence-prediction inconsistency & invalid task understanding
#
# 🔬 CLINICAL IMPACT:
#    • Sepsis prediction: 41.3/100
#    • Mortality prediction: 57.1/100
#    • Aki prediction: 53.5/100
# Best prompt approach: zhu_2024b_zero_shot_preprocessor with PULSE score: 50.63352685427296

# %% [markdown]
# ## Model Metrics

# %%
df_results = LLMAnalyzer.load_metrics_from_prompt_approaches(base_output_dir, prompt_approaches)

# %%
LLMAnalyzer.plot_metrics(
    df_results, group=["prompting_id"], title_prefix="GPT-4o - ",
)
# Out:
# C:\Users\janbe\Documents\GitHub Repos\pulse\src\eval\llm_analyzer.py:719: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = plot_df.groupby(["Group", "Metric"], as_index=False).agg(

# %%
LLMAnalyzer.plot_metrics(
    df_results,
    group=["task_id", "prompting_id"],
    title_prefix="GPT-4o - ",
)
# Out:
# C:\Users\janbe\Documents\GitHub Repos\pulse\src\eval\llm_analyzer.py:719: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = plot_df.groupby(["Group", "Metric"], as_index=False).agg(

# %%
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# Analysis of best prompting approach

# %%
prompt_dropdown = widgets.Dropdown(
    options=prompt_approaches,
    value=best_prompt_approach[0],
    description='Prompt Approach:',
    style={'description_width': 'initial'}
)
display(prompt_dropdown)
# Out:
# Dropdown(description='Prompt Approach:', index=1, options=('sarvari_2024_aggregation_preprocessor', 'zhu_2024b…

# %%
best_approach_path = os.path.join(
    base_output_dir, prompt_dropdown.value
)
print(f"Loading metadata from: {best_approach_path}")
print("======================================================")
cat_files = LLMAnalyzer.categorize_files([best_approach_path], verbose=False)
df_mdata = LLMAnalyzer.load_metadata(cat_files["metadata_files"])
# Out:
# Loading metadata from: C:\Users\janbe\Documents\GitHub Repos\pulse\output_to_keep\results_benchmark\llms\gpt4o\zhu_2024b_zero_shot_preprocessor
# ======================================================
# Model Name: GPT4o, Task: aki, Dataset: eicu, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: aki, Dataset: hirid, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: aki, Dataset: miiv, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: mortality, Dataset: eicu, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: mortality, Dataset: hirid, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: mortality, Dataset: miiv, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: sepsis, Dataset: eicu, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: sepsis, Dataset: hirid, Timestamp: 20250622_142837
# Model Name: GPT4o, Task: sepsis, Dataset: miiv, Timestamp: 20250622_142837

# %%
LLMAnalyzer.print_approach_summary(df_mdata)
# Out:
#         <h3>Summary of Approach</h3>
#         <ul>
#             <li><b>Number of samples:</b> 6,189</li>
#             <li><b>Tasks:</b> aki, mortality, sepsis</li>
#             <li><b>Datasets:</b> eicu, hirid, miiv</li>
#             <li><b>Predicted diagnoses:</b> not-aki, aki, not-mortality, mortality, sepsis, not-sepsis</li>
#             <li><b>Total inference time:</b> 4.50 h</li>
#             <li><b>Total input tokens:</b> 21,727,931</li>
#             <li><b>Total output tokens:</b> 649,558</li>
#         </ul>
# <style type="text/css">
# #T_779e5_row0_col2, #T_779e5_row0_col4, #T_779e5_row1_col4, #T_779e5_row1_col6, #T_779e5_row2_col4, #T_779e5_row8_col11 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_779e5_row0_col6, #T_779e5_row2_col6, #T_779e5_row6_col11 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_779e5_row0_col11, #T_779e5_row3_col4, #T_779e5_row4_col2, #T_779e5_row4_col4, #T_779e5_row4_col6, #T_779e5_row5_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_779e5_row1_col2, #T_779e5_row6_col2, #T_779e5_row7_col2, #T_779e5_row8_col2 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_779e5_row1_col11 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_779e5_row2_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_779e5_row2_col11 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_779e5_row3_col2 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_779e5_row3_col6, #T_779e5_row5_col2 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_779e5_row3_col11 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_779e5_row4_col11 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_779e5_row5_col6 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_779e5_row5_col11 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_779e5_row6_col4, #T_779e5_row7_col4, #T_779e5_row8_col4 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_779e5_row6_col6 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_779e5_row7_col6 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_779e5_row7_col11 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_779e5_row8_col6 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_779e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_779e5_level0_col0" class="col_heading level0 col0" >task</th>
#       <th id="T_779e5_level0_col1" class="col_heading level0 col1" >dataset</th>
#       <th id="T_779e5_level0_col2" class="col_heading level0 col2" >mean_inference_time</th>
#       <th id="T_779e5_level0_col3" class="col_heading level0 col3" >total_inference_time</th>
#       <th id="T_779e5_level0_col4" class="col_heading level0 col4" >mean_input_tokens</th>
#       <th id="T_779e5_level0_col5" class="col_heading level0 col5" >total_input_tokens</th>
#       <th id="T_779e5_level0_col6" class="col_heading level0 col6" >mean_output_tokens</th>
#       <th id="T_779e5_level0_col7" class="col_heading level0 col7" >total_output_tokens</th>
#       <th id="T_779e5_level0_col8" class="col_heading level0 col8" >positive_samples</th>
#       <th id="T_779e5_level0_col9" class="col_heading level0 col9" >negative_samples</th>
#       <th id="T_779e5_level0_col10" class="col_heading level0 col10" >total_samples</th>
#       <th id="T_779e5_level0_col11" class="col_heading level0 col11" >pos_neg_ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_779e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_779e5_row0_col0" class="data row0 col0" >aki</td>
#       <td id="T_779e5_row0_col1" class="data row0 col1" >eicu</td>
#       <td id="T_779e5_row0_col2" class="data row0 col2" >2.49s</td>
#       <td id="T_779e5_row0_col3" class="data row0 col3" >2449.98s</td>
#       <td id="T_779e5_row0_col4" class="data row0 col4" >3277</td>
#       <td id="T_779e5_row0_col5" class="data row0 col5" >3224745</td>
#       <td id="T_779e5_row0_col6" class="data row0 col6" >86</td>
#       <td id="T_779e5_row0_col7" class="data row0 col7" >84867</td>
#       <td id="T_779e5_row0_col8" class="data row0 col8" >305</td>
#       <td id="T_779e5_row0_col9" class="data row0 col9" >679</td>
#       <td id="T_779e5_row0_col10" class="data row0 col10" >984</td>
#       <td id="T_779e5_row0_col11" class="data row0 col11" >0.45</td>
#     </tr>
#     <tr>
#       <th id="T_779e5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_779e5_row1_col0" class="data row1 col0" >aki</td>
#       <td id="T_779e5_row1_col1" class="data row1 col1" >hirid</td>
#       <td id="T_779e5_row1_col2" class="data row1 col2" >2.53s</td>
#       <td id="T_779e5_row1_col3" class="data row1 col3" >2484.65s</td>
#       <td id="T_779e5_row1_col4" class="data row1 col4" >3277</td>
#       <td id="T_779e5_row1_col5" class="data row1 col5" >3218383</td>
#       <td id="T_779e5_row1_col6" class="data row1 col6" >84</td>
#       <td id="T_779e5_row1_col7" class="data row1 col7" >82083</td>
#       <td id="T_779e5_row1_col8" class="data row1 col8" >159</td>
#       <td id="T_779e5_row1_col9" class="data row1 col9" >823</td>
#       <td id="T_779e5_row1_col10" class="data row1 col10" >982</td>
#       <td id="T_779e5_row1_col11" class="data row1 col11" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_779e5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_779e5_row2_col0" class="data row2 col0" >aki</td>
#       <td id="T_779e5_row2_col1" class="data row2 col1" >miiv</td>
#       <td id="T_779e5_row2_col2" class="data row2 col2" >2.52s</td>
#       <td id="T_779e5_row2_col3" class="data row2 col3" >2476.29s</td>
#       <td id="T_779e5_row2_col4" class="data row2 col4" >3277</td>
#       <td id="T_779e5_row2_col5" class="data row2 col5" >3224759</td>
#       <td id="T_779e5_row2_col6" class="data row2 col6" >86</td>
#       <td id="T_779e5_row2_col7" class="data row2 col7" >84922</td>
#       <td id="T_779e5_row2_col8" class="data row2 col8" >229</td>
#       <td id="T_779e5_row2_col9" class="data row2 col9" >755</td>
#       <td id="T_779e5_row2_col10" class="data row2 col10" >984</td>
#       <td id="T_779e5_row2_col11" class="data row2 col11" >0.30</td>
#     </tr>
#     <tr>
#       <th id="T_779e5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_779e5_row3_col0" class="data row3 col0" >mortality</td>
#       <td id="T_779e5_row3_col1" class="data row3 col1" >eicu</td>
#       <td id="T_779e5_row3_col2" class="data row3 col2" >4.42s</td>
#       <td id="T_779e5_row3_col3" class="data row3 col3" >441.66s</td>
#       <td id="T_779e5_row3_col4" class="data row3 col4" >7866</td>
#       <td id="T_779e5_row3_col5" class="data row3 col5" >786638</td>
#       <td id="T_779e5_row3_col6" class="data row3 col6" >124</td>
#       <td id="T_779e5_row3_col7" class="data row3 col7" >12439</td>
#       <td id="T_779e5_row3_col8" class="data row3 col8" >7</td>
#       <td id="T_779e5_row3_col9" class="data row3 col9" >93</td>
#       <td id="T_779e5_row3_col10" class="data row3 col10" >100</td>
#       <td id="T_779e5_row3_col11" class="data row3 col11" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_779e5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_779e5_row4_col0" class="data row4 col0" >mortality</td>
#       <td id="T_779e5_row4_col1" class="data row4 col1" >hirid</td>
#       <td id="T_779e5_row4_col2" class="data row4 col2" >4.77s</td>
#       <td id="T_779e5_row4_col3" class="data row4 col3" >477.08s</td>
#       <td id="T_779e5_row4_col4" class="data row4 col4" >7870</td>
#       <td id="T_779e5_row4_col5" class="data row4 col5" >787001</td>
#       <td id="T_779e5_row4_col6" class="data row4 col6" >131</td>
#       <td id="T_779e5_row4_col7" class="data row4 col7" >13080</td>
#       <td id="T_779e5_row4_col8" class="data row4 col8" >11</td>
#       <td id="T_779e5_row4_col9" class="data row4 col9" >89</td>
#       <td id="T_779e5_row4_col10" class="data row4 col10" >100</td>
#       <td id="T_779e5_row4_col11" class="data row4 col11" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_779e5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_779e5_row5_col0" class="data row5 col0" >mortality</td>
#       <td id="T_779e5_row5_col1" class="data row5 col1" >miiv</td>
#       <td id="T_779e5_row5_col2" class="data row5 col2" >4.47s</td>
#       <td id="T_779e5_row5_col3" class="data row5 col3" >446.60s</td>
#       <td id="T_779e5_row5_col4" class="data row5 col4" >7867</td>
#       <td id="T_779e5_row5_col5" class="data row5 col5" >786671</td>
#       <td id="T_779e5_row5_col6" class="data row5 col6" >121</td>
#       <td id="T_779e5_row5_col7" class="data row5 col7"

# %%
metrics_report = cat_files['metrics_report_files'][0]
df_metrics = pd.read_json(metrics_report)
df_metrics
# Out:
#   model_id    task_id dataset                      prompting_id  \
# 0    GPT4o  mortality    eicu  zhu_2024b_zero_shot_preprocessor
# 1    GPT4o  mortality   hirid  zhu_2024b_zero_shot_preprocessor
# 2    GPT4o  mortality    miiv  zhu_2024b_zero_shot_preprocessor
# 3    GPT4o        aki    eicu  zhu_2024b_zero_shot_preprocessor
# 4    GPT4o        aki   hirid  zhu_2024b_zero_shot_preprocessor
# 5    GPT4o        aki    miiv  zhu_2024b_zero_shot_preprocessor
# 6    GPT4o     sepsis    eicu  zhu_2024b_zero_shot_preprocessor
# 7    GPT4o     sepsis   hirid  zhu_2024b_zero_shot_preprocessor
# 8    GPT4o     sepsis    miiv  zhu_2024b_zero_shot_preprocessor
#
#            run_id                                    metrics_summary
# 0  20250622142837  {'overall': {'auroc': 0.784, 'auprc': 0.39, 'n...
# 1  20250622142837  {'overall': {'auroc': 0.666, 'auprc': 0.319, '...
# 2  20250622142837  {'overall': {'auroc': 0.785, 'auprc': 0.614, '...
# 3  20250622142837  {'overall': {'auroc': 0.623, 'auprc': 0.431, '...
# 4  20250622142837  {'overall': {'auroc': 0.605, 'auprc': 0.276, '...
# 5  20250622142837  {'overall': {'auroc': 0.615, 'auprc': 0.437, '...
# 6  20250622142837  {'overall': {'auroc': 0.599, 'auprc': 0.059000...
# 7  20250622142837  {'overall': {'auroc': 0.673, 'auprc': 0.249, '...
# 8  20250622142837  {'overall': {'auroc': 0.35100000000000003, 'au...

# %%
# Save metrics to results.json using the LLMAnalyzer method
added_count, updated_count = LLMAnalyzer.save_metrics_to_results_json(
    metrics_report_path=metrics_report,
    results_json_path="../docs/results.json"
)
# Out:
# Updating existing record: model_id='GPT4o', prompting_id='zhu_2024b_zero_shot_preprocessor', task_id='mortality', dataset='eicu', run_id='20250622_142837'
# Updating existing record: model_id='GPT4o', prompting_id='zhu_2024b_zero_shot_preprocessor', task_id='mortality', dataset='hirid', run_id='20250622_142837'
# Updating existing record: model_id='GPT4o', prompting_id='zhu_2024b_zero_shot_preprocessor', task_id='mortality', dataset='miiv', run_id='20250622_142837'
# Updating existing record: model_id='GPT4o', prompting_id='zhu_2024b_zero_shot_preprocessor', task_id='aki', dataset='eicu', run_id='20250622_142837'
# Updating existing record: model_id='GPT4o', prompting_id='zhu_2024b_zero_shot_preprocessor', task_id='aki', dataset='hirid', run_id='20250622_142837'
# Updating existing record: model_id='GPT4o', prompting_id='zhu_2024b_zero_shot_preprocessor', task_id='aki', dataset='miiv', run_id='20250622_142837'
# Updating existing record: model_id='GPT4o', prompting_id='zhu_2024b_zero_shot_preprocessor', task_id='sepsis', dataset='eicu', run_id='20250622_142837'
# Updating existing record: model_id='GPT4o', prompting_id='zhu_2024b_zero_shot_preprocessor', task_id='sepsis', dataset='hirid', run_id='20250622_142837'
# Updating existing record: model_id='GPT4o', prompting_id='zhu_2024b_zero_shot_preprocessor', task_id='sepsis', dataset='miiv', run_id='20250622_142837'
# Results saved to ../docs/results.json
# Added 0 new records, updated 9 existing records
# Total records in results.json: 74
